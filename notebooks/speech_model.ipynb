# %% [markdown]
# # **Cree Audio Simple KNN Matcher**

# %%
import os
import librosa
import numpy as np
import pandas as pd
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
from IPython.display import Audio, display
from pathlib import Path
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
AUDIO_DIR = "../data/audio"
SAMPLE_RATE = 16000
N_MFCC = 13

# %% [markdown]
# 1. Load and extract MFCC features

# %%
def extract_mfcc(path, sr=SAMPLE_RATE, n_mfcc=N_MFCC):
    try:
        y, sr = librosa.load(path, sr=sr)
        mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=n_mfcc)
        mfcc_mean = np.mean(mfcc, axis=1)
        return mfcc_mean
    except Exception as e:
        print(f"Failed to process {path}: {e}")
        return None

# %% [markdown]
# 2. Build dataset of features and labels

# %%
def build_dataset(audio_dir):
    entries = []
    paths = []
    for fname in os.listdir(audio_dir):
        if fname.endswith(".mp3") or fname.endswith(".wav"):
            fpath = Path(audio_dir) / fname
            label = fname.replace(".mp3", "").replace(".wav", "").replace("_", " ")
            mfcc = extract_mfcc(fpath)
            if mfcc is not None:
                entries.append((label, mfcc))
                paths.append(str(fpath))
    if not entries:
        raise ValueError("No valid audio files found.")
    labels, features = zip(*entries)
    return np.vstack(features), list(labels), paths

# %%
# Load dataset
print("Extracting features from audio files...")
features, labels, paths = build_dataset(AUDIO_DIR)
print(f"Loaded {len(labels)} audio samples.")
# Out:
# Extracting features from audio files...
# Loaded 975 audio samples.

# %%
# array of audio fingerprints (MFCCs)
features
# Out:
# array([[-2.86015045e+02,  7.79737701e+01,  3.37328911e+00, ...,
#         -1.66387081e+00,  5.34664154e+00,  2.33658552e+00],
#        [-3.10722870e+02,  1.12454071e+02,  7.91447830e+00, ...,
#          1.26580238e+00,  3.68362117e+00,  1.10222836e+01],
#        [-2.41720184e+02,  1.20512955e+02,  1.91991825e+01, ...,
#          1.68058896e+00, -5.42074251e+00,  2.87276030e+00],
#        ...,
#        [-3.34146362e+02,  1.06140472e+02,  4.96253777e+00, ...,
#          5.64592600e+00, -2.37746382e+00,  7.48523712e+00],
#        [-2.74082642e+02,  9.88003616e+01,  2.04507351e+01, ...,
#          1.87584794e+00, -9.71282925e-03,  3.47740078e+00],
#        [-2.84845703e+02,  9.97648697e+01,  2.42921715e+01, ...,
#          2.76992273e+00, -7.52713251e+00,  4.94268703e+00]], dtype=float32)

# %%
# corresponding word(s) spoken in each audio
labels
# Out:
# ['acahkosak',
#  'achimoh',
#  'achimostamawâw',
#  'achimostaw',
#  'achimostawihk',
#  'achimostawik',
#  'achimostawin',
#  'achimostawinan',
#  'achimostawāw',
#  'achimostawēw',
#  'achimostawēwak',
#  'achimâw',
#  'achimēwak',
#  'achiwinam',
#  'achiwpayin',
#  'achiwīpayiw',
#  'acim',
#  'acimosisak',
#  'acosis',
#  'acoskēwinis',
#  'ahcanis',
#  'ahchi',
#  'ahchipiko',
#  'ahcānisak',
#  'ahih',
#  'ahihk',
#  'ahik',
#  'ahin',
#  'ahkamēyihtam',
#  'ahkamēyimoh',
#  'ahkamēyimōk',
#  'ahkwachāw',
#  'ahkwakamin',
#  'ahkwan',
#  'ahkwatihtā',
#  'ahkwatin',
#  'ahkwātisōwin',
#  'ahpō',
#  'ahtastā',
#  "ahtoskēwo' kamik",
#  'ahāw',
#  'ahēw',
#  'ahēwak',
#  'akahkway',
#  'akahkwayak',
#  'akawatamowin',
#  'akayāsemoh',
#  'akayāsemōwin',
#  'akihchike',
#  'akihcikēwin',
#  'akihta',
#  'akihtamaw',
#  'akihtāsowin',
#  'akihtāsōna',
#  'akim',
#  'akos',
#  'akoskôwahchikē',
#  'akotā',
#  'akwaha',
#  'akwahpisōwin',
#  'akwamohcikēwin',
#  'akwana',
#  'akwanahikana',
#  'akwâna',
#  'akwānahā',
#  'akāwācikēwin',
#  'akāwāstēskamok',
#  'amaciwēnēkānohtēwin',
#  'amisk',
#  'amiskosākahikan',
#  'amiskwak',
#  'amiskwayiwa',
#  'amiskwayān',
#  'amiskwayāna',
#  'anikwacās',
#  'aniskamanak',
#  'anāskāna',
#  'apacihcikan',
#  'apacikcikana',
#  'apahkwācēsak',
#  'apih',
#  'apihkāta',
#  'apihkē',
#  'apihkēwin',
#  'apihkēwina',
#  'apihtāpiw',
#  'apik',
#  'apiscacihkos',
#  'apisesiw',
#  'apisēsiw',
#  'apitān',
#  'aposōyahtikwa',
#  'apoy',
#  'apoyak',
#  'apwēsiwin',
#  'apāchih',
#  'apēhtāwsēyaw',
#  "apēw' kamik",
#  "as'pēyimoh",
#  'asahpicēkēwin',
#  'asam',
#  'asamās',
#  'asamāw',
#  'asamēna',
#  'asawāpam',
#  'asci',
#  'asikan',
#  'asikanak',
#  'asiniysisak',
#  'asiniywaciya',
#  'asinēyak',
#  'askihk',
#  'askihkohkānis',
#  'askipahkwēsikan',
#  'askipwāw',
#  'askipwāwa',
#  'askiwiyās',
#  'askiy',
#  'askāhtik',
#  'askāw',
#  'askāwewan',
#  'askō',
#  'asonē',
#  'asotamōwin',
#  'asowacikan',
#  'asowatā',
#  'aspapōwin',
#  'aspihci',
#  'aspin',
#  'aspinikan',
#  'aspitahkoskākan',
#  'asta',
#  'astawēha',
#  'astawēna',
#  'astawēska',
#  'astotina',
#  'aswēhta',
#  'aswēyim',
#  'asāhpis',
#  'asēn',
#  'asēna',
#  'asēpita',
#  'asēsina',
#  'asōwa',
#  'asōwatāw',
#  'asōwatēw',
#  'atamiskaw',
#  'atamiskākē',
#  'atamiskākēwak',
#  'atawēyihta',
#  'ate',
#  'atimapi',
#  'atimapik',
#  'atoska',
#  'atoskaw',
#  'atoskehkēk',
#  'atoskāta',
#  'atoskē',
#  'atoskēwin',
#  'atāmihk',
#  'atāmihkok',
#  'atāmin',
#  'atāmēw',
#  'atāwewikamikwa',
#  'atāwākē',
#  'atāwākēk',
#  'atāwē',
#  'atāwēk',
#  'atē',
#  'awa',
#  'awas',
#  'awasita',
#  'awasitē',
#  'awatā',
#  'awih',
#  'awēna',
#  'awēnāna',
#  'awēnāwa',
#  'awēta',
#  'awēte',
#  'awēyak',
#  'ayah',
#  'ayahci',
#  'ayahk',
#  'ayamihtā',
#  'ayamihā',
#  'ayamihāwin',
#  'ayamihēw kēsikāw',
#  'ayewinisā',
#  'ayikisis',
#  'ayinānēw',
#  'ayinānēwosāp',
#  'ayisk',
#  'ayiwāk',
#  'ayiwēpi',
#  'ayā',
#  'ayēkipēsim',
#  'ayēwinisā',
#  'ayōskan',
#  'cahcahkaha',
#  'cahcahkinosēw',
#  'cahcāmōwin',
#  'cahka',
#  'cahkin',
#  'cahkāha',
#  'cahkās',
#  'ce',
#  'chēpataha',
#  'cihcēkin',
#  'cihcēkinin',
#  'cihcēkwahcikē',
#  'cikāstēpayihcēkan',
#  'cipahikanis',
#  'cāh',
#  'cēka',
#  'cēkaha',
#  'cēkahikan',
#  'cēki',
#  'cēpatahikē',
#  'cēsi',
#  'cēsihiwēwin',
#  'cēsimiwēw',
#  'cēskwa',
#  'cēsta',
#  'cēstahikan',
#  'cēstin',
#  'ekay ekaya',
#  'ekay wiya',
#  'ekoni',
#  'ekonihi',
#  'ekospēhk',
#  'ekosāni',
#  'ekosēsi',
#  'ekote',
#  'ekōsani',
#  'ekōsi',
#  'etahkōmēw',
#  'etohta',
#  'ewako ohci',
#  'ewako or ēko',
#  'eyik',
#  'hay! hay!',
#  'hey! hey!',
#  'ihkwā',
#  'ihtakon',
#  'ihtakow',
#  'ikamā',
#  'isihcikātōwin',
#  'isihkāsow',
#  'isihtāw',
#  'iskipēw',
#  'iskona',
#  'iskonikan',
#  'iskotēw’ kamik',
#  'iskwayāch',
#  'iskwēw',
#  'iskwēwak',
#  'iskwēwowin',
#  'ispahtāw',
#  'ispayin',
#  'ispiciw',
#  'ispimihk',
#  'ispāyiw',
#  'isēhōw',
#  'itisa',
#  'itohta',
#  'itohtatā',
#  'itohtē',
#  'itwa',
#  'itwē',
#  'itwēw',
#  'itāpow',
#  'itātisiw',
#  'itāw',
#  'itēyihta',
#  'itōhōw',
#  'itōta',
#  'iyikohk',
#  'iyikopiwipēsim',
#  'iyinesowin',
#  'iyiwehk',
#  'iyāyaw',
#  'iyāyikohk',
#  'iyāyitē',
#  'kah!',
#  'kah-kimōwan',
#  'kah-kitow',
#  'kah-kēyāskōw',
#  'kahcitina',
#  'kahkan',
#  'kahke',
#  'kahkihtwām',
#  'kahkominakāk',
#  'kahkwēyihtam',
#  'kahkākow',
#  'kahkē',
#  'kahkēwak-ohkē-k',
#  'kahkēwak-ohkē',
#  'kakatāch',
#  'kakwecihkemowina',
#  'kakwē',
#  'kakwēcihkēmōwin',
#  'kakwēyāhiwin',
#  'kakwēyāhōwin',
#  'kakāyawisiw',
#  'kakē',
#  'kakēpātis',
#  'kakēskim',
#  'kakē -ayāwāw',
#  'kamik',
#  'kanakē',
#  'kanakēs',
#  'kanawāpahta',
#  'kanawāpam',
#  'kanawēyihta',
#  'kanawēyim',
#  'kanwapokēwin',
#  'kanācih',
#  'kanātastēw',
#  'kanātatisōwin',
#  'kanātisi-w',
#  'kanātisiwin',
#  'kapēsiw',
#  'kapēsiwin',
#  'kapēyayihk',
#  'kaskam',
#  'kaskatinōwipēsim',
#  'kaskihow',
#  'kaskihtāw',
#  'kaskihtāwin',
#  'kaskihēw',
#  'kaskikwācikē',
#  'kaskikwāsoh',
#  'kaskikwāsowin',
#  'kaskikātēsin',
#  'kaskim',
#  'kaskimihk',
#  'kaskina',
#  'kaskitēwacāpō',
#  'kaskāpahtew',
#  'kaskāpasam',
#  'kaskēyihtam',
#  'kaskēyimēw',
#  'kasēcihceēwin',
#  'kawa',
#  'kawisimo',
#  'kawiwēpin',
#  'kayahtē',
#  'kayesowina',
#  'kayāsēs',
#  'kayēsowin',
#  'kayēyisiw',
#  'ka kē',
#  'ka wayēsimiht',
#  'kehcinahōw',
#  'kehcinā',
#  'kehcināho',
#  'kehitwēw',
#  'kehkwāhākēsis',
#  'kekway',
#  'kepihtinkewin',
#  'ki-pe',
#  'ki',
#  'kihci',
#  'kihcēyihta kakihcēyihta',
#  'kihcē pēkiskwēwin',
#  'kihkahtoskōwak',
#  'kihkahtōwak',
#  'kihkām',
#  'kihkāmin',
#  'kihkāmāw',
#  'kihkāmēw',
#  'kihpē',
#  'kihtimikan',
#  'kihēwak',
#  'kikawacin',
#  'kimōtiw',
#  'kinosesis',
#  'kinosēw',
#  'kinosēwak',
#  'kinwēs',
#  'kipaha-kitōn',
#  'kipaha',
#  'kipatahtam',
#  'kipiskam',
#  'kipiskaw',
#  'kipē',
#  'kipōyon',
#  'kisikwatiw',
#  'kisin',
#  'kisinpēsim',
#  'kisiwāsōw',
#  'kisiwāsōwin',
#  'kiskinohamakosiw',
#  'kiskēciwān',
#  'kiskēsik',
#  'kisāstaw',
#  'kisēpiyākanē',
#  'kisēpēkinīkēwin',
#  'kitahamaw',
#  'kitahamākē',
#  'kitayān',
#  'kitimākinaw',
#  'kitimākinākē',
#  'kitimākēyim',
#  'kitimākēyimiso',
#  'kitohcikan',
#  'kitā',
#  'kitātsōwin',
#  'kiyapiko',
#  'kiyām',
#  'kiyāmāta',
#  'kohkōsak',
#  'kohtaskway',
#  'kotak',
#  'kotaka',
#  'kweyask',
#  'kwāskohti',
#  'kwētāmāwin',
#  'kwēyāho',
#  'kācikewin',
#  'kācikēwin',
#  'kāhkiyaw',
#  'kākwak',
#  'kākēcihiwēwin',
#  'kākēcihiwēwina',
#  'kākēhcisāyāwin',
#  'kākēsimōw',
#  'kāmwātapiwin',
#  'kāmwāteyihtākosiwin',
#  'kāmwātisiw',
#  'kāmwātisiwin',
#  'kām¯wātan',
#  'kās',
#  'kāsihkwē',
#  'kāskaha',
#  'kāskina',
#  'kāskipāsōw',
#  'kāsēcihcē',
#  'kāsēcihcēw',
#  'kāsēha',
#  'kāsēhkwankān',
#  'kāsēyākanē',
#  'kāsō',
#  'kāsōw',
#  'kātā',
#  'kātāk',
#  'kāwih',
#  'kāya',
#  'kāyawiya',
#  'kāyawātisiw',
#  'kāyān',
#  'kāyāwāw',
#  'kēci',
#  'kēcikon',
#  'kēcikona',
#  'kēhokēwin',
#  'kēhsāspinē',
#  'kēhsēyihtam',
#  'kēko',
#  'kēkway',
#  'kēkāc',
#  'kēkā -mitātaht',
#  'kēmōcinākosiw',
#  'kēpa',
#  'kēsastā',
#  'kēsi',
#  'kēsiska',
#  'kēskahamā',
#  'kēskasākay',
#  'kēskasākaya',
#  'kēskicāsis',
#  'kēskisa',
#  'kēso',
#  'kēspin',
#  'kēspinata',
#  'kēstawāw',
#  'kēsāc',
#  'kēsōsōwin',
#  'kētahtawē',
#  'kētasikanē',
#  'kētaskisinē',
#  'kētastotinē',
#  'kēwācawasis',
#  'kēwē',
#  'kēyanaw',
#  'kēyiwēhk',
#  'kēyokē',
#  'kīmōwanāpoy',
#  'kōhkomināw',
#  'kōna',
#  'kōtakak',
#  'maci',
#  'macostēha',
#  'macātisiwin',
#  'macātisēwin',
#  'mahikansak',
#  'mahti',
#  'mahtāmin',
#  'mahēhkān',
#  'mamihcim',
#  'manicôs',
#  'manisa',
#  'manitō kēsikāw',
#  'mansosowin',
#  'manācih',
#  'manācihitok',
#  'masinaha',
#  'masinahikē',
#  'masinahikēwin',
#  'masinipayowin',
#  'maskehkēwāpoy',
#  "maskihkēw' kamik",
#  'maskisin',
#  'maskisina',
#  'maskosis',
#  'matwānche',
#  'matōwehtākosōwin',
#  'mayahtihkowayan',
#  'mayaw',
#  'ma or mah',
#  'mekisihkahcikē',
#  'mescacākansak',
#  'metonē ka kāyāwsēwin',
#  'mihcētwāw',
#  'mihkoskātāsk',
#  'mihkwāpoy',
#  'mihtih',
#  'mikisowipēsim',
#  'minihkwācikan',
#  'minihkwē',
#  'mināhin',
#  'minēkwācikana',
#  'minōsak',
#  'minōsis',
#  'misawāc',
#  'misi',
#  'misipisiwak',
#  'misiweyahtik',
#  'misiwē',
#  'misiwētē',
#  'miskotākaya',
#  'miskwamiy',
#  'miskwāmē',
#  'mistahi',
#  'mistamēk',
#  'mistatim',
#  'mistatimwak',
#  'mistayāpēw',
#  'mistik',
#  'mitoni',
#  'mitâsak',
#  'mitās',
#  'mitāsak',
#  'mitātaht',
#  'moscosisak',
#  'mosis',
#  'mostosak',
#  'moya',
#  'mwēstas',
#  'māci',
#  'mācihtā',
#  'mācika',
#  'mācē',
#  'mācēk',
#  'māh',
#  'māka',
#  'mākwā',
#  'māmaskātamowin',
#  'māmawi',
#  'māmihci',
#  'māmitonēyihta',
#  'māmākwahcikē',
#  'māmāsēs',
#  'māna',
#  'māskisina',
#  'māskwak',
#  'māskōch',
#  'mātoh',
#  'māyacihkos',
#  'māyatihkwak',
#  'māyatōtamōwin',
#  'māyi',
#  'māyipayiwin',
#  'mēci',
#  'mēcimāpoy',
#  'mēkwā',
#  'mēkwāc',
#  'mēna',
#  'mēnisihkān',
#  'mētawē',
#  "mētāwew' kamik",
#  'mēyokēkway',
#  'mēyonākosiw',
#  'mēyoskamin',
#  'mēyosēhōwin',
#  'mēyo ayāwin',
#  'mōniyāskwēw',
#  'mōswa',
#  'mōw',
#  'na',
#  'naci',
#  'nah',
#  'nahew',
#  'nahēyikohk',
#  'nakē',
#  'namakekway',
#  'namoya',
#  'namwac',
#  'namēkos',
#  'namēkōs',
#  'nanāskomōw',
#  'napēch',
#  'naskwahamākē',
#  'naspāci',
#  'nawach',
#  'nawach piko',
#  'nayestāw',
#  'nayāhta',
#  'nehiyawē',
#  'nehtāciwēcowan',
#  'nepisēyāhtik',
#  'newo kīsikaw',
#  'ni',
#  'nihtā',
#  'nika',
#  'nikamōh',
#  "nikotwāsi'sāp",
#  'nikotwāsik',
#  'nikotwāsi kīsikāw',
#  'nikâwe',
#  'nimosôm',
#  'nipā',
#  'nipāw’ kamik',
#  'nipē',
#  'nipēwin',
#  'nipēwāpoy',
#  'nisitohta',
#  'niskak',
#  'niskipēsim',
#  'niskā',
#  'nistam',
#  'nisto',
#  'nistosāp',
#  'nitaw',
#  'nitotamāw',
#  'nohkom',
#  'nohtâwe',
#  'nohtē',
#  'nomoya wihkac',
#  'notokwēw',
#  'nā',
#  'nāh',
#  'nānapawishk',
#  'nānapoh',
#  'nānapēc',
#  'nānitaw',
#  'nāta',
#  'nātamaw',
#  'nāway',
#  'nēci',
#  'nēhi',
#  'nēmanēta',
#  'nēmihto',
#  'nēmāh',
#  'nēpawi',
#  'nēpin',
#  'nēso',
#  'nēsohkamaw',
#  'nēsosāp',
#  'nēstwāyāwin',
#  'nēstānaw',
#  'nēstōsēwin',
#  'nēta',
#  'nētē',
#  'nēwo',
#  'nēwosāp',
#  'nēyanan',
#  'nēyananosāp',
#  'nēyānān',
#  'nīkāmōwin',
#  'nīsto kīsikaw',
#  'nīyāno kīsikāw',
#  'nōcikwēsiw',
#  'nōsēmahkēsis',
#  'nōtinkākān',
#  'o',
#  'ohcitaw',
#  'ohphōwipēsim',
#  'ohpikin',
#  'ohpikiw',
#  'ohpēw',
#  'ohtēsikēwin',
#  'okehkwahakēs',
#  'okinēy',
#  'omātōw',
#  'onikohtēw',
#  'onōcihitowipēsim',
#  'opaskawēhopēsim',
#  'osihtā',
#  'oski',
#  'oskinikiskwew',
#  'oskātāsk',
#  'osām',
#  "osāw'pihēsēs",
#  'osāwās',
#  'otahōwēw',
#  'otatoskēw',
#  'otēhimin',
#  'otēhipak',
#  'owāstāhikēw',
#  'oyēh',
#  'pa-pamōhtēw',
#  'pa',
#  'pahkopē',
#  'pahkopēk',
#  'pahkopēwin',
#  'pahkwēsikan',
#  'pahkēkinosākay',
#  'pahpi',
#  'pahpiskich',
#  'pahpāhsces',
#  'pahpētos',
#  'pakowayān',
#  'pakwahtēhon',
#  'pakwahtēhona',
#  'pamihcikē',
#  'pamēpicēwin',
#  'papāmih or papami',
#  'pekiskwās',
#  'peyakwayih',
#  'picih',
#  'picēkwās',
#  'pihkahcēwāpōs',
#  'pihtaw',
#  'pihtawētāsān',
#  'pihtikwē',
#  'pihtwā',
#  'pihēsēsak',
#  'pikwēta',
#  'pikwētē',
#  'pimich',
#  "piminawasow' kamik",
#  'pimipahtā',
#  'pimātisi',
#  "pimēy atāwēw' kamik",
#  "pipon' asākay",
#  'pipon',
#  'piponasksisina',
#  'piponasākay',
#  'piponasākaya',
#  'pisastēhikan',
#  'pisisak',
#  'piweyihtamowin',
#  'poko',
#  'poko or piko',
#  'ponihtā',
#  'pwākomowin',
#  'pāhkwayākan',
#  'pākahkām',
#  'pāschi',
#  'pāsci',
#  'pāstēwahtik',
#  'pē',
#  'pēh',
#  'pēhcōnēs',
#  'pēhoh',
#  'pēhok',
#  'pēhowin',
#  'pēhta',
#  'pēhtākōsiwin',
#  'pēkiskwewina',
#  'pēsimohkān',
#  'pēsimohkānis',
#  'pēsiw',
#  'pēyak',
#  'pēyakosāp',
#  'pēyakwayak',
#  'pēyakwāw',
#  'pōna',
#  'pōni',
#  'pōnih',
#  'pōnāyamihēw kēsikāw',
#  'pōnēyim',
#  'pōsihtā',
#  'pōsik',
#  'pōtōma',
#  'sakāw',
#  'sakāwēyiniw',
#  'sapopēwin',
#  "simākanisēw' kamik",
#  'sipwehtē',
#  'sohkakihtēw',
#  'soniskwatahikēwkamik',
#  'sākahikan',
#  'sākih',
#  'sākēwēw',
#  'sāsākowāpiskos',
#  'sēhkos',
#  'sēkahikākan',
#  'sēkahikākana',
#  'sēkipatwā',
#  'sēmāk',
#  'sēnikēwin',
#  'sēstakwaya',
#  'sēsēp',
#  'sēsēpak',
#  'sēsēpaskihk',
#  'sēsēpisisak',
#  'sēwihtākan',
#  'sēwāpoy',
#  'sōhktisiwin',
#  'sōminahtik',
#  'sōminapoy',
#  "sōniskwātahikēw' kamik",
#  'sōskwāch',
#  'ta',
#  'tah',
#  'tahkascikan',
#  'tahkascēkana',
#  'tahto',
#  'tahtokēsikāw',
#  'tahtotipiskāw',
#  'tahtwayisiyniw',
#  'tahtwāw',
#  'tahtwāwiyak',
#  'tako',
#  'takwahhiminā',
#  'takwamohcikan',
#  'takwākin',
#  'tanehki',
#  'tanihi',
#  'taspwāw',
#  "tehtapiw' askisina",
#  'tihtipahpinewin',
#  'tipiskāki',
#  'tipāpiskōcikan',
#  'tohtōsāpoy',
#  'tāhkāmāpoy',
#  'tāhkōhch',
#  'tāna',
#  'tānanima',
#  'tānihi',
#  'tānimayikohk',
#  'tānisi',
#  'tānispēhk',
#  'tānisēkwa',
#  'tānita',
#  'tānitahto',
#  'tānitahtwāw',
#  'tānitē',
#  'tāniwehkāk',
#  'tāniwā',
#  'tāniwē',
#  'tāniwēhā',
#  'tānsāwa',
#  'tānsēsa',
#  'tānēhkanima',
#  'tāpiskōch',
#  'tēpakohpwāw',
#  'tēpakohpōsāp',
#  'tēpakōhp',
#  'wa',
#  'wapiskatim',
#  'wawiyas',
#  'wawēsēw',
#  'wawēyēw',
#  "wayawēw' tēhtapowin",
#  "wayāwēw' kamik",
#  'wihcēkaskosēy',
#  'wihkāch',
#  'wihpēm',
#  'wihtaskāta',
#  'wihtāmaw',
#  'wiyawāw',
#  'wiya or',
#  'wiysta',
#  'wāhiyāw',
#  'wāpim',
#  'wāpiskipahkēkin',
#  'wāpiwin',
#  'wāposak',
#  'wāsakām',
#  'wāsaskotēnikan',
#  'wāskesiwak',
#  'wāskēsōw',
#  'wāstāhikēwin',
#  'wāwi',
#  'wāwiyak',
#  'wāwēs',
#  'wāyipēyāw',
#  'wēkihtōwin',
#  'wēkinikan',
#  'wēkiw',
#  'wēpayōwēwin',
#  'wēpin',
#  'wēpina',
#  'wēsakacihp',
#  'wēskacān',
#  'wēyas',
#  'wēyatwēwin',
#  'wēyākan',
#  'wēyākanēw-kisēpēkinikan',
#  'ya',
#  'yah',
#  'yōtin',
#  'ācahkōs',
#  'āchimok',
#  'āchimow',
#  'ācosisāk',
#  'āh',
#  "āhkosēw' kāmik",
#  'āhāsiw',
#  'āhāsiwak',
#  'ākosimowin',
#  'ākwâha',
#  'ākwāskaw',
#  'āmachōwē',
#  'āmiskōs',
#  'ānwehtaw',
#  'ānwihtawēw',
#  'āpahah',
#  'āpihkona',
#  'āpihtā',
#  'āpisimōsak',
#  'āpēhoh',
#  'āpēwina',
#  'āsastā',
#  'āsay',
#  'āskiya',
#  'āsotamōwin',
#  'āstam',
#  'āstisak',
#  'āstotin',
#  'āta',
#  'ātawiya',
#  'ātayohkaw',
#  'ātiht',
#  'ātimapi',
#  'ātimwak',
#  'ātos',
#  'āwasōwin',
#  'āyētaw',
#  'ēci',
#  'ēkatē',
#  'ēkihceyihta',
#  'ēki eki',
#  'ēkonik',
#  'ēkotōwa',
#  'ēkwa',
#  'ēkwah',
#  'ēkwayāc',
#  'ēkwāna',
#  'ēkwānima',
#  'ēmihkwānis',
#  'ēmihkwānisak',
#  'ēsa',
#  'ēsi',
#  'ēsko',
#  'ētamahcihow',
#  'ētikwē',
#  'ētōta',
#  'ēwako āwa',
#  'ēwē or ēwēh',
#  'ēyiwēhk',
#  'ōhi',
#  'ōhtēwāpoy',
#  'ōhōwak',
#  'ōki',
#  'ōma',
#  'ōskēsēhōwin',
#  'ōta',
#  'ōtāpihkēw',
#  'ōtē',
#  'ōyēh']

# %% [markdown]
# 3. Fit Nearest Neighbors model

# %% [markdown]
# This prepares a search engine: “If I give you a new fingerprint, tell me the closest 3 matches.”

# %%
knn = NearestNeighbors(n_neighbors=3, metric='cosine')
knn.fit(features)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=3)

# %% [markdown]
# 4. Function to query new audio

# %%
def query_audio(audio_path):
    print(f"\n🔎 Querying: {audio_path}")
    vec = extract_mfcc(audio_path).reshape(1, -1)
    distances, indices = knn.kneighbors(vec)
    print("\n🎯 Top Matches:")
    for i, idx in enumerate(indices[0]):
        print(f"{i+1}. {labels[idx]} (distance: {distances[0][i]:.3f})")
        display(Audio(paths[idx]))

# %%
query_audio("../data/audio/acim.mp3")
# Out:
# 🔎 Querying: ../data/audio/acim.mp3
#
# 🎯 Top Matches:
# 1. acim (distance: 0.000)
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 2. itwa (distance: 0.001)
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# 3. māci (distance: 0.002)
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **Cree Audio Whisper + KNN Matcher**

# %%
import os
import torch
import torchaudio
import librosa
import numpy as np
import pandas as pd
from sklearn.neighbors import NearestNeighbors
from transformers import WhisperProcessor, WhisperModel
from IPython.display import Audio, display
import json
import joblib
import streamlit as st

# %%
# Set path to audio files
AUDIO_DIR = "../data/wav/"

# %% [markdown]
# Load Audio Files

# %%
def load_audio(path, sample_rate=16000):
    wav, sr = torchaudio.load(path)
    if sr != sample_rate:
        wav = torchaudio.functional.resample(wav, sr, sample_rate)
    return wav.mean(dim=0).numpy(), sample_rate  # mono

# %% [markdown]
# Load Whisper model and processor

# %%
processor = WhisperProcessor.from_pretrained("openai/whisper-small")
model = WhisperModel.from_pretrained("openai/whisper-small")
model.eval()
model = model.to("cpu")

# %% [markdown]
# Extract Whisper embedding (use encoder output)

# %%
def extract_whisper_embedding(path):
    audio, sr = load_audio(path)
    inputs = processor(audio, sampling_rate=sr, return_tensors="pt")
    input_features = inputs.input_features.to(model.device)
    with torch.no_grad():
        encoder_out = model.encoder(input_features)[0]
    return encoder_out.mean(dim=1).cpu().numpy().squeeze()  # average embedding

# %% [markdown]
# Build dataset (features + labels)

# %%
def build_dataset(audio_dir):
    features, labels, paths = [], [], []
    audio_files = [f for f in os.listdir(audio_dir) if f.endswith('.wav')]  # Only .wav files
    total_files = len(audio_files)

    for idx, fname in enumerate(audio_files, 1):
        label = fname.replace(".wav", "").replace("_", " ")
        path = os.path.join(audio_dir, fname)
        try:
            emb = extract_whisper_embedding(path)
            features.append(emb)
            labels.append(label)
            paths.append(path)
            print(f"[{idx}/{total_files}] ✅ Processed: {fname}")
        except Exception as e:
            print(f"[{idx}/{total_files}] ❌ Failed: {fname} | Error: {e}")

    return np.stack(features), labels, paths

# %%
print("🔄 Extracting embeddings from dataset...")
features, labels, paths = build_dataset(AUDIO_DIR)
print(f"✅ Done. Total samples: {len(labels)}")
# Out:
# 🔄 Extracting embeddings from dataset...
# [1/975] ✅ Processed: acahkosak.wav
# [2/975] ✅ Processed: achimoh.wav
# [3/975] ✅ Processed: achimostamawâw.wav
# [4/975] ✅ Processed: achimostaw.wav
# [5/975] ✅ Processed: achimostawihk.wav
# [6/975] ✅ Processed: achimostawik.wav
# [7/975] ✅ Processed: achimostawin.wav
# [8/975] ✅ Processed: achimostawinan.wav
# [9/975] ✅ Processed: achimostawāw.wav
# [10/975] ✅ Processed: achimostawēw.wav
# [11/975] ✅ Processed: achimostawēwak.wav
# [12/975] ✅ Processed: achimâw.wav
# [13/975] ✅ Processed: achimēwak.wav
# [14/975] ✅ Processed: achiwinam.wav
# [15/975] ✅ Processed: achiwpayin.wav
# [16/975] ✅ Processed: achiwīpayiw.wav
# [17/975] ✅ Processed: acim.wav
# [18/975] ✅ Processed: acimosisak.wav
# [19/975] ✅ Processed: acosis.wav
# [20/975] ✅ Processed: acoskēwinis.wav
# [21/975] ✅ Processed: ahcanis.wav
# [22/975] ✅ Processed: ahchi.wav
# [23/975] ✅ Processed: ahchipiko.wav
# [24/975] ✅ Processed: ahcānisak.wav
# [25/975] ✅ Processed: ahih.wav
# [26/975] ✅ Processed: ahihk.wav
# [27/975] ✅ Processed: ahik.wav
# [28/975] ✅ Processed: ahin.wav
# [29/975] ✅ Processed: ahkamēyihtam.wav
# [30/975] ✅ Processed: ahkamēyimoh.wav
# [31/975] ✅ Processed: ahkamēyimōk.wav
# [32/975] ✅ Processed: ahkwachāw.wav
# [33/975] ✅ Processed: ahkwakamin.wav
# [34/975] ✅ Processed: ahkwan.wav
# [35/975] ✅ Processed: ahkwatihtā.wav
# [36/975] ✅ Processed: ahkwatin.wav
# [37/975] ✅ Processed: ahkwātisōwin.wav
# [38/975] ✅ Processed: ahpō.wav
# [39/975] ✅ Processed: ahtastā.wav
# [40/975] ✅ Processed: ahtoskēwo'_kamik.wav
# [41/975] ✅ Processed: ahāw.wav
# [42/975] ✅ Processed: ahēw.wav
# [43/975] ✅ Processed: ahēwak.wav
# [962/975] ✅ Processed: ētōta.wav
# [963/975] ✅ Processed: ēwako_āwa.wav
# [964/975] ✅ Processed: ēwē_or_ēwēh.wav
# [965/975] ✅ Processed: ēyiwēhk.wav
# [966/975] ✅ Processed: ōhi.wav
# [967/975] ✅ Processed: ōhtēwāpoy.wav
# [968/975] ✅ Processed: ōhōwak.wav
# [969/975] ✅ Processed: ōki.wav
# [970/975] ✅ Processed: ōma.wav
# [971/975] ✅ Processed: ōskēsēhōwin.wav
# [972/975] ✅ Processed: ōta.wav
# [973/975] ✅ Processed: ōtāpihkēw.wav
# [974/975] ✅ Processed: ōtē.wav
# [975/975] ✅ Processed: ōyēh.wav
# ✅ Done. Total samples: 975

# %% [markdown]
# Fit KNN model

# %%
knn = NearestNeighbors(n_neighbors=3, metric="cosine")
knn.fit(features)
# Out:
# NearestNeighbors(metric='cosine', n_neighbors=3)

# %% [markdown]
# Saving features, Labels, Paths and Model

# %%
# Save features
np.save("../models/audio/features.npy", features)

# Save labels and paths
with open("../models/audio/labels.json", "w", encoding="utf-8") as f:
    json.dump(labels, f)
with open("../models/audio/paths.json", "w", encoding="utf-8") as f:
    json.dump(paths, f)

# Save KNN model
joblib.dump(knn, "../models/audio/knn_model.pkl")
# Out:
# ['../models/audio/knn_model.pkl']

# %% [markdown]
# Load saved model + data

# %%
features = np.load("../models/audio/features.npy")
with open("../models/audio/labels.json", "r", encoding="utf-8") as f:
    labels = json.load(f)
with open("../models/audio/paths.json", "r", encoding="utf-8") as f:
    paths = json.load(f)

knn = joblib.load("../models/audio/knn_model.pkl")

# %% [markdown]
# Search function to match query audio

# %%
def query_audio(audio_path, top_k=3):
    print(f"\n🔎 Querying: {audio_path}")
    query_emb = extract_whisper_embedding(audio_path).reshape(1, -1)
    distances, indices = knn.kneighbors(query_emb, n_neighbors=top_k)
    print("\n🎯 Top Matches:")
    for i, idx in enumerate(indices[0]):
        print(f"{i+1}. {labels[idx]} (distance: {distances[0][i]:.2f})")
        display(Audio(paths[idx]))

# %%
# ✅ Example usage:
query_audio("../data/audio/akwaha.mp3")
# Out:
# 🔎 Querying: ../data/audio/akwaha.mp3
#
# 🎯 Top Matches:
# 1. akwaha (distance: 0.00)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 2. ākwâha (distance: 0.00)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 3. māmawi (distance: 0.00)
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# UI with Streamlit

# %%
# st.title("🧠 Cree Word Audio Matcher")
# st.markdown("Upload a Cree word audio file (MP3 or WAV) and get the closest known matches.")

# uploaded_file = st.file_uploader("Upload audio file", type=["wav", "mp3"])

# if uploaded_file is not None:
#     with tempfile.NamedTemporaryFile(delete=False, suffix=os.path.splitext(uploaded_file.name)[-1]) as tmp:
#         tmp.write(uploaded_file.read())
#         tmp_path = tmp.name

#     st.audio(tmp_path)
#     with st.spinner("Analyzing..."):
#         query_emb = extract_whisper_embedding(tmp_path).reshape(1, -1)
#         distances, indices = knn.kneighbors(query_emb, n_neighbors=5)

#     st.success("Top Matches:")
#     for i, idx in enumerate(indices[0]):
#         st.write(f"{i+1}. **{labels[idx]}** (distance: {distances[0][i]:.2f})")
#         st.audio(paths[idx])
# Out:
# 2025-06-20 10:07:12.303
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\Hend-PC\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
